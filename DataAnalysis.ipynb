# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeyadora/college/blob/main/DataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Exploratory data analysis (EDA) on Iris Dataset using Python**

# %%
#Load the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Load the data
iris = pd.read_csv('iris.csv')


#View the data
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
iris_setso = iris.loc[iris["variety"] == "Setosa"];
iris_virginica = iris.loc[iris["variety"] == "Virginica"];
iris_versicolor = iris.loc[iris["variety"] == "Versicolor"];
plt.plot(iris_setso["petal.length"],np.zeros_like(iris_setso["petal.length"]), 'o')
plt.plot(iris_versicolor["petal.length"],np.zeros_like(iris_versicolor["petal.length"]), 'o')
plt.plot(iris_virginica["petal.length"],np.zeros_like(iris_virginica["petal.length"]), 'o')
plt.grid()
plt.show()

# %%
sns.FacetGrid(iris,hue="variety",size=5) \
.map(plt.scatter,'sepal.length','sepal.width') \
.add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");
sns.pairplot(iris,hue="variety",size=3);
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
